# %% [markdown]
# ### Netflix-Dataset
# #### Big Data Analysis with Python
# ##### (Himanshi Kumari)

# %% [markdown]
# ![netflix-logo.png](attachment:netflix-logo.png)

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Himanshi\Desktop\exl data analyst\Netflix_Dataset.csv")

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# #### Explore Data With Python Basuc commands

# %%
data.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# ...

# %%
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.size
# Out:
# 85679

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=7789, step=1)

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
#data.info()

# %% [markdown]
# ### Task. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace=True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# ### Task. 2) Is there any Null Value present in any column ? Show with Heat-map.

# %%
data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# #### Seaborn library(Heat map)

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())

# %% [markdown]
# ### Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %% [markdown]
# ##### using isin()

# %%
data[data['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ##### using str.conatins()

# %%
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ##### creating a new column in date time format

# %%
data['Date_of_release']=pd.to_datetime(data['Release_Date'])

# %%
data.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description Date_of_release
# 0  In a future where the elite inhabit an island ...      2020-08-14
# ...

# %%
data.dtypes
# Out:
# Show_Id                    object
# Category                   object
# Title                      object
# Director                   object
# Cast                       object
# Country                    object
# Release_Date               object
# Rating                     object
# Duration                   object
# Type                       object
# Description                object
# Date_of_release    datetime64[ns]
# dtype: object

# %%
data['Date_of_release'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_of_release, dtype: int64

# %% [markdown]
# #### BAR GRAPH

# %%
# Add the essential library matplotlib
import matplotlib.pyplot as plt

# create the data
Year=data['Date_of_release']
movie_counts = data['Date_of_release'].dt.year.value_counts()

# Plot the data
plt.bar(Year,movie_counts, color='Blue')

# Add X Label on X-axis
plt.xlabel('Year')

# Add X Label on X-axis
plt.ylabel('Number of Movies and Tv shows released')

# Add a title to graph
plt.title('Released movies and Tv shows')
# Show the plot
plt.show()
# Out:
# C:\Users\Himanshi\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-4ae9cb87667f> in <module>
#       7
#       8 # Plot the data
# ----> 9 plt.bar(Year,movie_counts, color='Blue')
#      10
#      11 # Add X Label on X-axis
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
# ...

# %%
a=dt.year.value_counts()
sns.barplot.a

# %% [markdown]
# ### Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
data.head(3)

# %% [markdown]
# ##### Using value count function

# %%
a=data.Category.value_counts()

# %% [markdown]
# ##### Using groupby function

# %%
data.groupby('Category').Category.count()

# %% [markdown]
# ##### Bar Graph Using Cuntplot

# %%
import seaborn as sns

# %%
sns.countplot(data['Category'])

# %% [markdown]
# ### Q. 4) Show all the Movies that were released in year 2020.

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Date_of_release
# 0  In a future where the elite inhabit an island ...      2020-08-14
# 1  After a devastating earthquake hits Mexico Cit...      2016-12-23

# %%
data['Year']=data['Date_of_release'].dt.year   # use to create new year column

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Date_of_release    Year
# 0  In a future where the elite inhabit an island ...      2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit...      2016-12-23  2016.0

# %%
data[data['Year'].isin([2000])]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_of_release, Year]
# Index: []

# %%
data[(data['Category'] == 'Movie') & (data['Year'] == 2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
print(type(data.Year))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data[data['Year'] == 2016]
# Out:
#      Show_Id Category               Title  \
# 1         s2    Movie                7:19
# 25       s26    Movie            (T)ERROR
# 35       s36    Movie           #Rucker50
# 59       s60    Movie     1000 Rupee Note
# 62       s63    Movie          13 Cameras
# ...      ...      ...                 ...
# 7735   s7734  TV Show   You're My Destiny
# 7739   s7738    Movie         Young Tiger
# 7742   s7741  TV Show   Your lie in April
# 7769   s7768  TV Show  Zindagi Gulzar Hai
# 7772   s7771    Movie             Zinzana
#
#                                     Director  \
# 1                          Jorge Michel Grau
# 25    Lyric R. Cabral, David Felix Sutcliffe
# 35                     Robert McCullough Jr.
# 59                            Shrihari Sathe
# 62                            Victor Zarcoff
# ...                                      ...
# 7735                                     NaN
# 7739                                  Mu Chu
# ...

# %%
data[(data['Category'] == 'Movie')]
# Out:
#      Show_Id Category                                    Title  \
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# ...      ...      ...                                      ...
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %% [markdown]
# ### Q. 5) Show only the Titles of all TV Shows that were released in India only.

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Date_of_release    Year
# 0  In a future where the elite inhabit an island ...      2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit...      2016-12-23  2016.0

# %%
data[(data['Country']=='India')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...

# %%
data[(data['Category']=='TV Show') & (data['Country']=='India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ### Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Date_of_release    Year
# 0  In a future where the elite inhabit an island ...      2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit...      2016-12-23  2016.0

# %%
data['Director'].value_counts().head(10)  # to show top 10 director
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Ryan Polito                8
# Name: Director, dtype: int64

# %% [markdown]
# ### Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Date_of_release    Year
# 0  In a future where the elite inhabit an island ...      2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit...      2016-12-23  2016.0

# %%
data[data['Type']=='Comedies']
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
data[((data['Category']=='Movie') & (data['Type']=='Comedies'))|(data['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                      89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# ### Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
data.Cast
# Out:
# 0       João Miguel, Bianca Comparato, Michel Gomes, R...
# 1       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3       Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#                               ...
# 7784    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                              Nasty C
# 7787                           Adriano Zumbo, Rachel Khoo
# 7788                                                  NaN
# Name: Cast, Length: 7787, dtype: object

# %%
data[data['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-99100bfe290c> in <module>
# ----> 1 data[data['Cast'].str.contains('Tom Cruise')]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2968
#    2969         # Do we have a (boolean) 1d indexer?
# -> 2970         if com.is_bool_indexer(key):
#    2971             return self._getitem_bool_array(key)
#    2972
#
# ~\Anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     128             if not lib.is_bool_array(key):
#     129                 if isna(key).any():
# --> 130                     raise ValueError(na_msg)
#     131                 return False
#     132             return True
#
# ValueError: cannot index with vector containing NA / NaN values

# %%
new_data=data.dropna()

# %%
new_data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description Date_of_release    Year
# 1  After a devastating earthquake hits Mexico Cit...      2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow...      2018-12-20  2018.0

# %%
new_data[new_data.Cast.str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description Date_of_release  \
# 3860  Through chance, human action, past history and...      2020-01-01
# 5071  A fast-talking yuppie is forced to slow down w...      2019-07-01
#
#         Year
# 3860  2020.0
# 5071  2019.0

# %% [markdown]
# ### Q. 9) What are the different Ratings defined by Netflix ?

# %%
new_data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description Date_of_release    Year
# 1  After a devastating earthquake hits Mexico Cit...      2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow...      2018-12-20  2018.0

# %%
new_data.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
new_data.Rating.nunique()
# Out:
# 14

# %% [markdown]
# #### Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
new_data.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
new_data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description Date_of_release    Year
# 1  After a devastating earthquake hits Mexico Cit...      2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow...      2018-12-20  2018.0

# %%
new_data[(new_data['Category']=='Movie') & (new_data['Rating']=='TV-14') &(new_data['Country']=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 34                           Michael Kennedy
# 608                              Jason Stone
# 1506                           Jason Bourque
# 3713  Jennifer Baichwal, Nicholas de Pencier
# 3956                     Jean-François Blais
# ...

# %%
new_data[(new_data['Category']=='Movie') & (new_data['Rating']=='TV-14') &(new_data['Country']=='Canada')].count()
# Out:
# Show_Id            9
# Category           9
# Title              9
# Director           9
# Cast               9
# Country            9
# Release_Date       9
# Rating             9
# Duration           9
# Type               9
# Description        9
# Date_of_release    9
# Year               9
# dtype: int64

# %%
new_data[(new_data['Category']=='Movie') & (new_data['Rating']=='TV-14') &(new_data['Country']=='Canada')].shape
# Out:
# (9, 13)

# %% [markdown]
# #### Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
new_data.head(1)
# Out:
#   Show_Id Category Title           Director  \
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating Duration                          Type  \
# 1  December 23, 2016  TV-MA   93 min  Dramas, International Movies
#
#                                          Description Date_of_release    Year
# 1  After a devastating earthquake hits Mexico Cit...      2016-12-23  2016.0

# %%
new_data[(new_data['Category'] =='TV Show') & (new_data['Rating']=='R') & (new_data['Year'] > 2016)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_of_release, Year]
# Index: []

# %%
new_data[(new_data['Year']>2018)]
# Out:
#      Show_Id Category       Title             Director  \
# 4         s5    Movie          21       Robert Luketic
# 6         s7    Movie         122      Yasir Al Yasiri
# 7         s8    Movie         187       Kevin Reynolds
# 8         s9    Movie         706        Shravan Kumar
# 13       s14    Movie       2,215  Nottapon Boonprakob
# ...      ...      ...         ...                  ...
# 7776   s7775    Movie      Zodiac        David Fincher
# 7780   s7779    Movie  Zombieland      Ruben Fleischer
# 7783   s7782    Movie        Zoom         Peter Hewitt
# 7784   s7783    Movie        Zozo          Josef Fares
# 7785   s7784    Movie      Zubaan          Mozez Singh
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 6     Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...
# ...

# %%
new_data[(new_data['Category']=='TV Show') & (new_data['Rating']=='R')]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_of_release, Year]
# Index: []

# %%
new_data[(new_data['Rating']=='R') &(new_data['Year'] > 2018)]
# Out:
#      Show_Id Category               Title                       Director  \
# 7         s8    Movie                 187                 Kevin Reynolds
# 14       s15    Movie                3022                     John Suits
# 65       s66    Movie             13 Sins                   Daniel Stamm
# 68       s69    Movie           14 Blades                     Daniel Lee
# 83       s84    Movie  20th Century Women                     Mike Mills
# ...      ...      ...                 ...                            ...
# 7659   s7658    Movie           Woodshock  Kate Mulleavy, Laura Mulleavy
# 7712   s7711    Movie       Yes, God, Yes                    Karen Maine
# 7738   s7737    Movie         Young Adult                  Jason Reitman
# 7776   s7775    Movie              Zodiac                  David Fincher
# 7780   s7779    Movie          Zombieland                Ruben Fleischer
#
#                                                    Cast  \
# ...

# %%
new_data[(new_data['Category']=='TV Show') & (new_data['Rating']=='R') &(new_data['Year']>2018)].shape
# Out:
# (0, 13)

# %% [markdown]
# ### Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
new_data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description Date_of_release    Year
# 1  After a devastating earthquake hits Mexico Cit...      2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow...      2018-12-20  2018.0

# %%
new_data['Duration'].unique()
# Out:
# array(['93 min', '78 min', '80 min', '123 min', '1 Season', '95 min',
#        '119 min', '118 min', '143 min', '103 min', '89 min', '91 min',
#        '149 min', '144 min', '124 min', '110 min', '128 min', '117 min',
#        '100 min', '99 min', '102 min', '104 min', '105 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '87 min', '109 min',
#        '101 min', '90 min', '113 min', '114 min', '130 min', '94 min',
#        '140 min', '135 min', '82 min', '70 min', '92 min', '164 min',
#        '83 min', '116 min', '84 min', '86 min', '120 min', '96 min',
#        '126 min', '75 min', '129 min', '77 min', '137 min', '148 min',
#        '121 min', '122 min', '176 min', '85 min', '22 min', '68 min',
#        '111 min', '29 min', '142 min', '168 min', '59 min', '108 min',
#        '44 min', '26 min', '156 min', '98 min', '57 min', '150 min',
#        '133 min', '115 min', '154 min', '127 min', '146 min', '136 min',
# ...

# %%
new_data['Duration'].dtypes
# Out:
# dtype('O')

# %%
new_data[['Mintues','Units']]= new_data['Duration'].str.split(' ',expand=True)
# Out:
# C:\Users\Himanshi\Anaconda3\lib\site-packages\pandas\core\frame.py:3494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
new_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
new_data.Mintues.max()
# Out:
# '99'

# %%
new_data.Mintues.min()
# Out:
# '1'

# %%
new_data.Mintues.mean()
# Out:
# inf

# %% [markdown]
# ### Q. 11) Which individual country has the Highest No. of TV Shows ?

# %%
new_data.head(1)
# Out:
#   Show_Id Category Title           Director  \
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating Duration                          Type  \
# 1  December 23, 2016  TV-MA   93 min  Dramas, International Movies
#
#                                          Description Date_of_release    Year  \
# 1  After a devastating earthquake hits Mexico Cit...      2016-12-23  2016.0
#
#   Mintues Units
# 1      93   min

# %%
data_tvshow=data[data['Category']=='TV Show']

# %%
data_tvshow
# Out:
#      Show_Id Category            Title            Director  \
# 5         s6  TV Show               46         Serdar Akar
# 132     s133  TV Show        7 (Seven)         Nizar Shafi
# 218     s219  TV Show  A Queen Is Born        Carla Barros
# 260     s261  TV Show         A.I.C.O.       Kazuya Murata
# 276     s277  TV Show     Abby Hatcher         Kyran Kelly
# ...      ...      ...              ...                 ...
# 7387   s7386  TV Show          Valeria       Inma Torrente
# 7402   s7401  TV Show           Velvet        Carlos Sedes
# 7494   s7493  TV Show   Watership Down          Noam Murro
# 7668   s7667  TV Show    World of Winx      Iginio Straffi
# 7723   s7722  TV Show              You  Lee Toland Krieger
#
#                                                    Cast  \
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# 132   Rahman, Havish, Regina Cassandra, Nandita Swet...
# 218                       Gloria Groove, Alexia Twister
# ...

# %%
data_tvshow.Country.value_counts()
# Out:
# United States              705
# United Kingdom             204
# Japan                      157
# South Korea                147
# India                       71
#                           ...
# United States, Colombia      1
# Spain, Italy                 1
# Taiwan, China                1
# India, Germany, France       1
# China, Hong Kong             1
# Name: Country, Length: 183, dtype: int64

# %%
data_tvshow.Country.value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# ###  Q. 12) How can we sort the dataset by Year ?

# %%
data.sort_values(by='Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %%
data.sort_values(by='Year',ascending=False)
# Out:
#      Show_Id Category                         Title                 Director  \
# 5564   s5564    Movie               Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie                     Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show                  Bling Empire                      NaN
# 5955   s5955    Movie              Taare Zameen Par               Aamir Khan
# 366     s367    Movie                     Al acecho      Francisco D'Eufemia
# ...      ...      ...                           ...                      ...
# 3374   s3375  TV Show                      Kikoriki                      NaN
# 3492   s3493  TV Show           La Familia P. Luche                      NaN
# 3946   s3947  TV Show                         Maron                      NaN
# 5138   s5138  TV Show                  Red vs. Blue                      NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                      NaN
#
# ...

# %%
data.sort_values(by='Year',ascending=True)
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %% [markdown]
# ### Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
data.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description Date_of_release    Year
# 0  In a future where the elite inhabit an island ...      2020-08-14  2020.0

# %%
data[(data['Category']=='Movie') & (data['Type']=='Dramas') | (data['Category']=='TV Show') & (data['Type']=='Kids TV')]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data[(data['Category']=='Movie') & (data['Type']=='Dramas')]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data[(data['Category']=='TV Show') & (data['Type']=='Kids TV')]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_of_release, Year]
# Index: []

# %%
data[(data['Type']=='Kids TV')]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_of_release, Year]
# Index: []
